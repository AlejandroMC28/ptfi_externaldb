# %%
import pandas as pd

# %% [markdown]
# ## Natural product database matches to origin organisms
#
# This notebook focuses on linking natural product databases to their origin organisms.
#
# By identifying the species associated with natural products, we can better understand their biological and ecological significance.

# %% [markdown]
# ### Supernatural 3 database
#
# The Supernatural 3 database contains information about natural products and their associated species.
#
# In this section, we load the Supernatural 3 database and extract species-related data for matched compounds.

# %% [markdown]
# Load Supernatural 3 database and subset of species related to the matched compounds

# %%
sp3 = pd.read_csv("../databases/full_data_download.csv", sep=";")
sp3_ptfi_species = pd.read_csv("../databases/supernatural_organisms_ptfi.csv")

# %%
sp3_ptfi_species.head()
# Out:
#            Organism Name        Pubchem/DOI Wiki Data Taxon source_sn_id
# 0  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
# 1   Cyclopia genistoides  10.1021/JF040097Z       Q15530980    SN0003173
# 2    Cyclopia intermedia  10.1021/JF040097Z       Q15531063    SN0003173
# 3      Cyclopia maculata  10.1021/JF040097Z       Q15531155    SN0003173
# 4       Cyclopia falcata  10.1021/JF040097Z       Q15530859    SN0003173

# %%
sp3_ptfi_species = sp3_ptfi_species.merge(sp3, left_on="source_sn_id", right_on="parent_id", how="inner")
sp3_ptfi_species.head()
# Out:
#            Organism Name        Pubchem/DOI Wiki Data Taxon source_sn_id  \
# 0  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
# 1  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
# 2  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
# 3  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
# 4  Cyclopia sessiliflora  10.1021/JF040097Z       Q15530719    SN0003173
#
#              id  parent_id                                   traditional_name  \
# 0     SN0003173  SN0003173  1,3,6,7-tetrahydroxy-2-[3,4,5-trihydroxy-6-(hy...
# 1  SN0003173-01  SN0003173  1,3,6,7-tetrahydroxy-2-[3,4,5-trihydroxy-6-(hy...
# 2  SN0003173-02  SN0003173  1,3,6,7-tetrahydroxy-2-[(2S,3R,4R,5R,6R)-3,4,5...
# 3  SN0003173-03  SN0003173  1,3,6,7-tetrahydroxy-2-[(2S,3R,4S,5S,6R)-3,4,5...
# 4  SN0003173-04  SN0003173  1,3,6,7-tetrahydroxy-2-[(2R,3R,4R,5S,6R)-3,4,5...
#
#                                           IUPAC_name  \
# 0  1,3,6,7-tetrahydroxy-2-[(2S,3R,4R,5S,6R)-3,4,5...
# 1  1,3,6,7-tetrahydroxy-2-[(2S,3R,4R,5S,6R)-3,4,5...
# 2  1,3,6,7-tetrahydroxy-2-[(2S,3R,4R,5R,6R)-3,4,5...
# 3  1,3,6,7-tetrahydroxy-2-[(2S,3R,4S,5S,6R)-3,4,5...
# 4  1,3,6,7-tetrahydroxy-2-[(2R,3R,4R,5S,6R)-3,4,5...
#
#                      inchi_key  \
# 0  AEDDIBAIWPIIBD-UHFFFAOYSA-N
# 1  AEDDIBAIWPIIBD-UHFFFAOYSA-N
# 2  AEDDIBAIWPIIBD-CYXGIEPOSA-N
# 3  AEDDIBAIWPIIBD-GQCSGYJFSA-N
# 4  AEDDIBAIWPIIBD-IEXOMYFASA-N
#
#                                               smiles  ... num_hba  \
# 0  OCC1OC(C(O)C(O)C1O)c2c(O)cc3Oc4cc(O)c(O)cc4C(=...  ...    11.0
# 1  OC[C@H]1OC([C@H](O)[C@H](O)[C@@H]1O)c2c(O)cc3O...  ...    11.0
# 2  OC[C@H]1O[C@H]([C@H](O)[C@@H](O)[C@H]1O)c2c(O)...  ...    11.0
# 3  OC[C@H]1O[C@H]([C@H](O)[C@H](O)[C@@H]1O)c2c(O)...  ...    11.0
# 4  OC[C@H]1O[C@@H]([C@H](O)[C@@H](O)[C@@H]1O)c2c(...  ...    11.0
#
#    num_amide_bonds  num_hetero_atoms  num_heavy_atoms  num_atoms  \
# 0              0.0              11.0             30.0       48.0
# 1              0.0              11.0             30.0       48.0
# 2              0.0              11.0             30.0       48.0
# 3              0.0              11.0             30.0       48.0
# 4              0.0              11.0             30.0       48.0
#
#    num_stereocenters  num_aromatic_rings  num_saturated_rings  \
# 0                5.0                 3.0                  1.0
# 1                5.0                 3.0                  1.0
# 2                5.0                 3.0                  1.0
# 3                5.0                 3.0                  1.0
# 4                5.0                 3.0                  1.0
#
#    num_aliphatic_rings  score
# 0                  1.0    1,0
# 1                  1.0    NaN
# 2                  1.0    NaN
# 3                  1.0    NaN
# 4                  1.0    NaN
#
# [5 rows x 26 columns]

# %%
sp3_ptfi_species = sp3_ptfi_species[["Organism Name", "inchi_key", "source_sn_id"]]
sp3_ptfi_species = (
    sp3_ptfi_species
    .groupby(['inchi_key', 'source_sn_id'], as_index=False)
    .agg({'Organism Name': '|'.join})
)
# Out:
#                         inchi_key source_sn_id  \
# 0     AEDDIBAIWPIIBD-CYXGIEPOSA-N    SN0003173
# 1     AEDDIBAIWPIIBD-GQCSGYJFSA-N    SN0003173
# 2     AEDDIBAIWPIIBD-IEXOMYFASA-N    SN0003173
# 3     AEDDIBAIWPIIBD-LHZXLERQSA-N    SN0003173
# 4     AEDDIBAIWPIIBD-MPZMQPASSA-N    SN0003173
# ...                           ...          ...
# 1165  ZSKDVJYWOHBGNI-UHFFFAOYSA-N    SN0479047
# 1166  ZTHSABILDCCHJR-XLKGFZLASA-N    SN0479713
# 1167  ZTHYODDOHIVTJV-UHFFFAOYSA-N    SN0479717
# 1168  ZZNVCZGRNCQHCQ-IBQWGDSDSA-N    SN0484542
# 1169  ZZNVCZGRNCQHCQ-JZSCMRTJSA-N    SN0484542
#
#                                           Organism Name
# 0     Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# 1     Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# 2     Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# 3     Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# 4     Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# ...                                                 ...
# 1165  Jungermannia exsertifolia|Chiloscyphus polyant...
# 1166  Prunus dulcis|Prunus dulcis|Prunus prostrata|P...
# 1167  Mangifera foetida|Mangifera indica|Alchornea g...
# 1168                                  Spinacia oleracea
# 1169  Spinacia oleracea|Spinacia oleracea|Spinacia o...
#
# [1170 rows x 3 columns]

# %% [markdown]
# Filter our organism database only to the InChiKeys found in the PTFI known subset

# %%
ptfi_dic = pd.read_csv("../databases/ptfi_dic.csv")
ptfi_known = ptfi_dic[~ptfi_dic["definition"].str.contains("unknown")].copy()
ptfi_known["inchi_key"] = ptfi_known["element_id"].str.replace("MET_", "")
ptfi_known_inchi = set(ptfi_known["inchi_key"].unique())
len(ptfi_known_inchi)
# Out:
# 900

# %%
sp3_ptfi_species = sp3_ptfi_species[sp3_ptfi_species["inchi_key"].isin(ptfi_known_inchi)]

# %% [markdown]
# ## LOTUS database
#
# The LOTUS database provides detailed information about natural product occurrences and their taxonomic classifications.
#
# In this section, we query the LOTUS MongoDB database to retrieve species information for compounds in the PTFI dataset.

# %% [markdown]
# ### LOTUS database setup
#
# We use the LOTUS (Natural Products Occurrence) MongoDB database to query species natural product information.
#
# ### Prerequisites
#
# A local MongoDB instance with the LOTUS NPOC2021 database is required for this analysis. The LOTUS MongoDB dump can be downloaded from the [LOTUS repository](https://lotus.naturalproducts.net/).

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27019/")  # Adjust if needed
db = client["NPOC2021"]
collection = db["lotusUniqueNaturalProduct"]

# %% [markdown]
# Function to query LOTUS information

# %%
def get_taxonomy_by_source(compound_inchikey: str):
    doc = collection.find_one({"inchikey": compound_inchikey})
    if not doc:
        return {"error": "Compound not found"}

    result = {
        "compound": doc.get("traditional_name", "Unknown"),
        "inchikey": compound_inchikey,
        "taxonomies": {}
    }

    taxonomy_data = doc.get("taxonomyReferenceObjects", {})
    for source, entries in taxonomy_data.items():
        if not isinstance(entries, dict):
            continue
        first_entry = list(entries.values())[0]
        if isinstance(first_entry, list) and first_entry:
            taxonomy = first_entry[0]
            organized = {
                "domain": taxonomy.get("domain") or taxonomy.get("superkingdom"),
                "kingdom": taxonomy.get("kingdom"),
                "phylum": taxonomy.get("phylum"),
                "class": taxonomy.get("classx"),
                "family": taxonomy.get("family"),
                "genus": taxonomy.get("genus"),
                "species": taxonomy.get("species"),
            }
            result["taxonomies"][source] = {k: v for k, v in organized.items() if v}

    return result

# %%
inchikey = "WUADCCWRTIWANL-UHFFFAOYSA-N"  # example: Biochanin A
taxonomy_info = get_taxonomy_by_source(inchikey)
taxonomy_info
# Out:
# {'compound': 'biochanin',
#  'inchikey': 'WUADCCWRTIWANL-UHFFFAOYSA-N',
#  'taxonomies': {'10$x$x$1128/AEM$x$x$57$x$x$2$x$x$434-439$x$x$1991': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium repens'},
#   '10$x$x$1002/JSSC$x$x$200500003': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Vitaceae',
#    'genus': 'Vitis',
#    'species': 'Vitis vinifera'},
#   '10$x$x$1021/JF00049A020': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium subterraneum'},
#   '10$x$x$1248/CPB$x$x$54$x$x$278': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Swartzia',
#    'species': 'Swartzia polyphylla'},
#   '10$x$x$1016/S0031-9422(00)89039-1': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia nitidula'},
#   '10$x$x$1080/10575639908041222': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Myristica',
#    'species': 'Myristica ceylanica'},
#   '10$x$x$1021/NP010606G': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Glycine',
#    'species': 'Glycine max'},
#   '10$x$x$1016/0304-3835(91)90044-I': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1016/0031-9422(88)80628-9': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Wisteria',
#    'species': 'Wisteria brachybotrys'},
#   '10$x$x$1002/JCCS$x$x$200100040': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Asteraceae',
#    'genus': 'Serratula',
#    'species': 'Serratula strangulata'},
#   '10$x$x$1002/CHIN$x$x$200052210': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Annonaceae',
#    'genus': 'Anaxagorea',
#    'species': 'Anaxagorea luzonensis'},
#   '10$x$x$1016/J$x$x$BMCL$x$x$2011$x$x$12$x$x$036': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia sissoo'},
#   '10$x$x$1016/S0021-9150(99)00029-5': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium subterraneum'},
#   '10$x$x$1007/BF02249145': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer flexuosum'},
#   '10$x$x$1016/S0031-9422(00)94601-6': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia spruceana'},
#   '10$x$x$1080/1478641031000103669': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Euchresta',
#    'species': 'Euchresta formosana'},
#   '10$x$x$1007/BF00595030': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Lupinus',
#    'species': 'Lupinus albus'},
#   '10$x$x$1016/S0031-9422(98)00709-2': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Virola',
#    'species': 'Virola surinamensis'},
#   '10$x$x$1016/S0031-9422(00)88458-7': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Thermopsis',
#    'species': 'Thermopsis macrophylla'},
#   '10$x$x$1016/S0031-9422(00)81307-2': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Bolusanthus',
#    'species': 'Bolusanthus speciosus'},
#   '10$x$x$1039/P19760000186': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Pericopsis',
#    'species': 'Pericopsis elata'},
#   '10$x$x$1055/S-2007-969907': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1002/CHIN$x$x$200432208': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Styphnolobium',
#    'species': 'Styphnolobium japonicum'},
#   '10$x$x$1016/J$x$x$PHYTOCHEM$x$x$2003$x$x$09$x$x$003': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Flemingia',
#    'species': 'Flemingia prostrata'},
#   '10$x$x$1016/S0378-8741(00)00285-3': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Andira',
#    'species': 'Andira inermis'},
#   '10$x$x$1016/J$x$x$FITOTE$x$x$2009$x$x$05$x$x$005': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Knema',
#    'species': 'Knema furfuracea'},
#   '10$x$x$21608/BFSA$x$x$2000$x$x$66404': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Crotalaria',
#    'species': 'Crotalaria thebaica'},
#   '10$x$x$1021/JF062148T': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Arachis',
#    'species': 'Arachis hypogaea'},
#   '10$x$x$1248/BPB$x$x$20$x$x$865': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Wisteria',
#    'species': 'Wisteria brachybotrys'},
#   '10$x$x$1016/S0021-9673(97)00989-8': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Glycine',
#    'species': 'Glycine max'},
#   '10$x$x$1248/CPB$x$x$52$x$x$1255': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Virola',
#    'species': 'Virola surinamensis'},
#   '10$x$x$1016/S0021-9673(01)01231-6': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1071/CH9850485': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Pinopsida',
#    'family': 'Podocarpaceae',
#    'genus': 'Sundacarpus',
#    'species': 'Sundacarpus amarus'},
#   '10$x$x$1016/J$x$x$TALANTA$x$x$2009$x$x$03$x$x$011': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium arvense'},
#   '10$x$x$1016/S0031-9422(00)85740-4': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Baptisia',
#    'species': 'Baptisia sphaerocarpa'},
#   '10$x$x$1016/S0003-2670(01)01370-8': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1248/CPB$x$x$40$x$x$2970': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Swartzia',
#    'species': 'Swartzia polyphylla'},
#   '10$x$x$1248/YAKUSHI1947$x$x$96$x$x$12_1486': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Pueraria'},
#   '10$x$x$1055/S-2002-35658': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Asteraceae',
#    'genus': 'Serratula',
#    'species': 'Serratula strangulata'},
#   '10$x$x$1021/NP0302450': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia nigrescens'},
#   '10$x$x$1016/S0031-9422(99)00489-6': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Myristica',
#    'species': 'Myristica malabarica'},
#   '10$x$x$1055/S-0028-1099407': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pannonicum'},
#   '10$x$x$1016/S0021-9673(01)96392-7': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1016/S0021-9673(96)00578-X': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1002/JPS$x$x$2600640504': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1016/0160-9327(76)90004-1': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium repens'},
#   '10$x$x$1016/0031-9422(79)80020-5': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Myroxylon',
#    'species': 'Myroxylon peruiferum'},
#   '10$x$x$1055/S-2007-967103': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Pycnanthus',
#    'species': 'Pycnanthus angolensis'},
#   '10$x$x$1021/NP50105A007': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Knema',
#    'species': 'Knema glomerata'},
#   '10$x$x$1016/S0021-9673(97)01070-4': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Pueraria'},
#   '10$x$x$1007/BF02969267': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1007/BF00599277': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer mogoltavicum'},
#   '10$x$x$1016/S0031-9422(01)00295-3': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Andira',
#    'species': 'Andira inermis'},
#   '10$x$x$1076/PHBI$x$x$37$x$x$1$x$x$54$x$x$6310': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia sissoo'},
#   '10$x$x$1007/BF00579982': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium aureum'},
#   '10$x$x$1007/BF00564927': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Andira',
#    'species': 'Andira inermis'},
#   '10$x$x$1016/S0031-9422(00)88981-5': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Virola',
#    'species': 'Virola caducifolia'},
#   '10$x$x$3906/KIM-1206-45': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia sissoides'},
#   '10$x$x$1021/NP960122Y': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Swartzia',
#    'species': 'Swartzia polyphylla'},
#   '10$x$x$1016/J$x$x$FITOTE$x$x$2011$x$x$10$x$x$007': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Ormosia',
#    'species': 'Ormosia henryi'},
#   '10$x$x$1016/J$x$x$FOODCHEM$x$x$2011$x$x$09$x$x$021': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Astragalus',
#    'species': 'Astragalus laxmannii'},
#   '10$x$x$1055/S-2006-957534': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Pueraria'},
#   '10$x$x$1016/S1570-0232(02)00079-X': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1002/(SICI)1099-1565(199707)8:4<176::AID-PCA351>3$x$x$0$x$x$CO;2-K': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myrtaceae',
#    'genus': 'Syzygium',
#    'species': 'Syzygium jambos'},
#   '10$x$x$1093/CHROMSCI/39$x$x$10$x$x$441': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cullen',
#    'species': 'Cullen corylifolia'},
#   '10$x$x$1021/JF991002+': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1093/OXFORDJOURNALS$x$x$JHERED$x$x$A102397': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1021/JF050448P': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$4268/CJCMM20140916': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia sissoides'},
#   '10$x$x$1007/BF02282376': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer mogoltavicum'},
#   '10$x$x$1016/S0031-9422(97)00802-9': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Sophora',
#    'species': 'Sophora secundiflora'},
#   '10$x$x$1016/J$x$x$BMCL$x$x$2015$x$x$07$x$x$017': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Moraceae',
#    'genus': 'Maclura',
#    'species': 'Maclura tricuspidata'},
#   '10$x$x$1021/NP000010D': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia frutescens'},
#   '10$x$x$1039/JR9620004906': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Andira',
#    'species': 'Andira inermis'},
#   '10$x$x$1021/NP50118A028': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Swartzia',
#    'species': 'Swartzia polyphylla'},
#   '10$x$x$1016/S0021-9673(00)91555-3': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Ononis',
#    'species': 'Ononis spinosa'},
#   '10$x$x$1080/14786419$x$x$2010$x$x$522577': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Myristicaceae',
#    'genus': 'Pycnanthus',
#    'species': 'Pycnanthus angolensis'},
#   '10$x$x$1016/0305-1978(81)90030-2': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer pungens'},
#   '10$x$x$1016/J$x$x$PHYTOCHEM$x$x$2003$x$x$08$x$x$010': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia oliveri'},
#   '10$x$x$1271/BBB$x$x$100878': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1021/NP970503R': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium subterraneum'},
#   '10$x$x$1016/J$x$x$FITOTE$x$x$2009$x$x$06$x$x$002': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia parviflora'},
#   '10$x$x$1016/J$x$x$PHYTOCHEM$x$x$2007$x$x$03$x$x$007': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Poaceae',
#    'genus': 'Gynerium',
#    'species': 'Gynerium sagittatum'},
#   '10$x$x$1021/JF60116A026': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Medicago',
#    'species': 'Medicago sativa'},
#   '10$x$x$1016/S0031-9422(97)00798-X': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1007/S11418-010-0407-8': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trigonella',
#    'species': 'Trigonella foenum-graecum'},
#   '10$x$x$1248/CPB$x$x$48$x$x$1219': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Annonaceae',
#    'genus': 'Anaxagorea',
#    'species': 'Anaxagorea luzonensis'},
#   '10$x$x$1016/0031-9422(74)85043-0': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia monetaria'},
#   '10$x$x$1007/BF00629811': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer songaricum'},
#   '10$x$x$1007/BF00629810': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1007/BF00630553': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium diffusum'},
#   '10$x$x$1007/BF00565710': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium medium'},
#   '10$x$x$1016/0031-9422(91)84117-B': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Liliopsida',
#    'family': 'Iridaceae',
#    'genus': 'Iris',
#    'species': 'Iris pseudacorus'},
#   '10$x$x$1016/S0021-9673(01)89464-4': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Ononis',
#    'species': 'Ononis spinosa'},
#   '10$x$x$1515/ZNC-1988-7-809': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1097/GME$x$x$0B013E318156F9D6': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1515/ZNC-1991-1-208': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Cicer',
#    'species': 'Cicer arietinum'},
#   '10$x$x$1016/S0031-9422(00)94255-9': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Echinospartum',
#    'species': 'Echinospartum horridum'},
#   '10$x$x$1515/ZNC-1985-9-1005': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Bolusanthus',
#    'species': 'Bolusanthus speciosus'},
#   '10$x$x$1016/J$x$x$FITOTE$x$x$2006$x$x$01$x$x$004': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1016/S0021-9673(99)00110-7': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Trifolium',
#    'species': 'Trifolium pratense'},
#   '10$x$x$1002/MRC$x$x$2138': {'domain': 'Eukaryota',
#    'kingdom': 'Archaeplastida',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Andira',
#    'species': 'Andira surinamensis'},
#   '10$x$x$1016/S0031-9422(00)89103-7': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia monetaria'},
#   '10$x$x$1002/(SICI)1099-1573(199903)13:2<163::AID-PTR405>3$x$x$0$x$x$CO;2-#': {'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Styphnolobium',
#    'species': 'Styphnolobium japonicum'},
#   '10$x$x$1021/NP900676Y': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia parviflora'},
#   '10$x$x$1016/0031-9422(81)85097-2': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Monopteryx',
#    'species': 'Monopteryx uaucu'},
#   '10$x$x$1007/S10600-019-02831-3': {'domain': 'Eukaryota',
#    'kingdom': 'Viridiplantae',
#    'phylum': 'Streptophyta',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia sissoides'},
#   '10$x$x$1016/0031-9422(83)80186-1': {'kingdom': 'Plantae',
#    'class': 'Magnoliopsida',
#    'family': 'Fabaceae',
#    'genus': 'Dalbergia',
#    'species': 'Dalbergia monetaria'}}}

# %% [markdown]
# Function to extract all species names assigned to a compound

# %%
def get_species_for_inchikeys(inchikey_list):
    query = {"inchikey": {"$in": inchikey_list}}
    cursor = collection.find(query)

    result = {}
    
    for doc in cursor:
        inchikey = doc.get("inchikey")
        species_set = set()
        taxonomy_data = doc.get("taxonomyReferenceObjects", {})

        for source_entries in taxonomy_data.values():
            if not isinstance(source_entries, dict):
                continue
            for org_list in source_entries.values():
                if isinstance(org_list, list):
                    for taxon in org_list:
                        species = taxon.get("species")
                        if species:
                            species_set.add(species)

        result[inchikey] = " | ".join(sorted(species_set))

    return result

# %%
species_lookup = get_species_for_inchikeys(list(ptfi_known_inchi))

# %%
lotus_ptfi_species = ptfi_known[['element_id', 'element_name', 'inchi_key']].copy()
lotus_ptfi_species['species'] = lotus_ptfi_species['inchi_key'].map(species_lookup)
lotus_ptfi_species = lotus_ptfi_species.dropna()

# %%
lotus_ptfi_species
# Out:
#                            element_id               element_name  \
# 0     MET_IBGBGRVKPALMCQ-UHFFFAOYSA-N    Protocatechuic aldehyde
# 1     MET_ZOAMBXDOGPRZLP-UHFFFAOYSA-N      1H-Indole-3-acetamide
# 3     MET_KKVZAVRSVHUSPL-GQCTYLIASA-N    2-Methoxycinnamaldehyde
# 4     MET_NITWSHWHQAQBAW-QPJJXVBHSA-N  Methyl 4-Hydroxycinnamate
# 6     MET_OCNYGKNIVPVPPX-HWKANZROSA-N            Methyl caffeate
# ...                               ...                        ...
# 1002  MET_KKSDGJDHHZEWEP-SNAWJCMRSA-N     3-Hydroxycinnamic acid
# 1003  MET_QAIPRVGONGVQAS-DUXPYHPUSA-N               Caffeic acid
# 1004  MET_NYPYHUZRZVSYKL-ZETCQYMHSA-N      3,5-Diiodo-L-tyrosine
# 1005  MET_BBZCPUCZKLTAJQ-UHFFFAOYSA-N        3-Methyl-2-oxindole
# 1006  MET_QIAFMBKCNZACKA-UHFFFAOYSA-N              Hippuric acid
#
#                         inchi_key  \
# 0     IBGBGRVKPALMCQ-UHFFFAOYSA-N
# 1     ZOAMBXDOGPRZLP-UHFFFAOYSA-N
# 3     KKVZAVRSVHUSPL-GQCTYLIASA-N
# 4     NITWSHWHQAQBAW-QPJJXVBHSA-N
# 6     OCNYGKNIVPVPPX-HWKANZROSA-N
# ...                           ...
# 1002  KKSDGJDHHZEWEP-SNAWJCMRSA-N
# 1003  QAIPRVGONGVQAS-DUXPYHPUSA-N
# 1004  NYPYHUZRZVSYKL-ZETCQYMHSA-N
# 1005  BBZCPUCZKLTAJQ-UHFFFAOYSA-N
# 1006  QIAFMBKCNZACKA-UHFFFAOYSA-N
#
#                                                 species
# 0     Actaea racemosa | Amomum subulatum | Amomum ts...
# 1     Apis cerana | Balansia epichloe | Citrus retic...
# 3     Cinnamomum aromaticum | Cinnamomum cassia | Ci...
# 4     Allium cepa | Alpinia blepharocalyx | Alpinia ...
# 6     Actaea racemosa | Ageratina adenophora | Alang...
# ...                                                 ...
# 1002  Balanophora tobiracola | Betula pubescens | Ch...
# 1003  Abies spectabilis | Abutilon indicum | Acalyph...
# 1004                        Homo sapiens | Mus musculus
# 1005                             Ceratocystis fimbriata
# 1006  Persea americana | Schizosaccharomyces pombe |...
#
# [480 rows x 4 columns]

# %% [markdown]
# ## COCONUT database
#
# The COCONUT database is a comprehensive collection of open natural products, including their taxonomic data.
#
# In this section, we load the COCONUT database and filter the data to include only compounds found in the PTFI dataset.

# %%
coco = pd.read_csv("../databases/coconut_csv-07-2025.csv", low_memory=False)

# %%
coco_species = coco[['standard_inchi_key', 'organisms']]
coco_species = coco_species.dropna()

# %%
ptfi_known_inchi
coco_species_ptfi = coco_species[coco_species['standard_inchi_key'].isin(ptfi_known_inchi)]
coco_species_ptfi
# Out:
#                  standard_inchi_key  \
# 158     BHQCQFFYRZLCQQ-OELDTZBJSA-N
# 723     GZSOSUNBTXMUFQ-YFAPSIMESA-N
# 735     OVBPIULPVIDEAO-LBPRGKRZSA-N
# 872     YWJXCIXBAKGUKZ-HJJNZUOJSA-N
# 1295    SJRACCTZSAUMGO-WIMVFMHDSA-N
# ...                             ...
# 435882  HELVNAROXHFAIE-DUWALXBPSA-N
# 436528  UCJQLVSIHYDTNQ-USACIQFYSA-N
# 492760  TUUBGLDJKKCMRH-LDSFXQROSA-N
# 592420  GXXXVFMBJGIYPK-RXSNYNEVSA-N
# 646128  YKRGDOXKVOZESV-WRJNSLSBSA-N
#
#                                                 organisms
# 158     Bos taurus|Bubalus bubalis|Calculus bovis arti...
# 723     Aesculus turbinata|Alnus alnobetula|Argyreia s...
# 735     FOOD SAKE|Foeniculum vulgare|Spinacia oleracea...
# 872     Aframomum amaniense|Alectoria divergens|Amaror...
# 1295          Ammi visnaga|Eranthis hyemalis (L.) Salisb.
# ...                                                   ...
# 435882                                Amaranthus cruentus
# 436528                                   Silybum marianum
# 492760                              Glycyrrhiza uralensis
# 592420                 Dipsacus asper|Strychnos axillaris
# 646128                             Paeonia officinalis L.
#
# [342 rows x 2 columns]

# %% [markdown]
# ## Merging and building the natural product-organism database
#
# In this section, we consolidate species data from the Supernatural 3, LOTUS, and COCONUT databases.
#
# The goal is to create a comprehensive dataset linking natural products to their origin organisms.

# %%
sp3_ptfi_species
# Out:
#                         inchi_key source_sn_id  \
# 13    AEDDIBAIWPIIBD-ZJKJAXBQSA-N    SN0003173
# 16    AEQDJSLRWYMAQI-UHFFFAOYSA-N    SN0003583
# 17    AHTRGGWSBFOEEG-BXDNVMCDSA-N    SN0006019
# 23    AIONOLUJZLIMTK-AWEZNQCLSA-N    SN0006614
# 25    AKZZXWNFVQXXFN-QHJPBWEBSA-N    SN0008409
# ...                           ...          ...
# 1155  ZROGCCBNZBKLEL-MPRHSVQHSA-N    SN0478424
# 1165  ZSKDVJYWOHBGNI-UHFFFAOYSA-N    SN0479047
# 1166  ZTHSABILDCCHJR-XLKGFZLASA-N    SN0479713
# 1167  ZTHYODDOHIVTJV-UHFFFAOYSA-N    SN0479717
# 1169  ZZNVCZGRNCQHCQ-JZSCMRTJSA-N    SN0484542
#
#                                           Organism Name
# 13    Cyclopia sessiliflora|Cyclopia genistoides|Cyc...
# 16    Corydalis turtschaninovii|Stephania venosa|Ech...
# 17    Fraxinus excelsior|Fraxinus excelsior|Fraxinus...
# 23    Citrus maxima|Citrus trifoliata|Citrus reticul...
# 25    Laggera crispata|Laggera crispata|Laggera cris...
# ...                                                 ...
# 1155  Smilax china|Smilax glabra|Garcinia mangostana...
# 1165  Jungermannia exsertifolia|Chiloscyphus polyant...
# 1166  Prunus dulcis|Prunus dulcis|Prunus prostrata|P...
# 1167  Mangifera foetida|Mangifera indica|Alchornea g...
# 1169  Spinacia oleracea|Spinacia oleracea|Spinacia o...
#
# [353 rows x 3 columns]

# %% [markdown]
# ### Standardize and merge all species data
#
# Now we'll merge the three datasets (SP3, LOTUS, COCONUT) into one comprehensive species database.

# %%
# Prepare SP3 data - rename columns and select relevant ones
sp3_for_merge = sp3_ptfi_species[['inchi_key', 'Organism Name']].copy()
sp3_for_merge = sp3_for_merge.rename(columns={'Organism Name': 'species_info'})
sp3_for_merge['source'] = 'SP3'

print("SP3 dataset shape:", sp3_for_merge.shape)
sp3_for_merge.head()
# Out:
# SP3 dataset shape: (353, 3)
#                       inchi_key  \
# 13  AEDDIBAIWPIIBD-ZJKJAXBQSA-N
# 16  AEQDJSLRWYMAQI-UHFFFAOYSA-N
# 17  AHTRGGWSBFOEEG-BXDNVMCDSA-N
# 23  AIONOLUJZLIMTK-AWEZNQCLSA-N
# 25  AKZZXWNFVQXXFN-QHJPBWEBSA-N
#
#                                          species_info source
# 13  Cyclopia sessiliflora|Cyclopia genistoides|Cyc...    SP3
# 16  Corydalis turtschaninovii|Stephania venosa|Ech...    SP3
# 17  Fraxinus excelsior|Fraxinus excelsior|Fraxinus...    SP3
# 23  Citrus maxima|Citrus trifoliata|Citrus reticul...    SP3
# 25  Laggera crispata|Laggera crispata|Laggera cris...    SP3

# %%
# Prepare LOTUS data - rename columns and select relevant ones
lotus_for_merge = lotus_ptfi_species[['inchi_key', 'species']].copy()
lotus_for_merge = lotus_for_merge.rename(columns={'species': 'species_info'})
lotus_for_merge['source'] = 'LOTUS'

print("LOTUS dataset shape:", lotus_for_merge.shape)
lotus_for_merge.head()
# Out:
# LOTUS dataset shape: (480, 3)
#                      inchi_key  \
# 0  IBGBGRVKPALMCQ-UHFFFAOYSA-N
# 1  ZOAMBXDOGPRZLP-UHFFFAOYSA-N
# 3  KKVZAVRSVHUSPL-GQCTYLIASA-N
# 4  NITWSHWHQAQBAW-QPJJXVBHSA-N
# 6  OCNYGKNIVPVPPX-HWKANZROSA-N
#
#                                         species_info source
# 0  Actaea racemosa | Amomum subulatum | Amomum ts...  LOTUS
# 1  Apis cerana | Balansia epichloe | Citrus retic...  LOTUS
# 3  Cinnamomum aromaticum | Cinnamomum cassia | Ci...  LOTUS
# 4  Allium cepa | Alpinia blepharocalyx | Alpinia ...  LOTUS
# 6  Actaea racemosa | Ageratina adenophora | Alang...  LOTUS

# %%
# Prepare COCONUT data - rename columns and select relevant ones
coco_for_merge = coco_species_ptfi[['standard_inchi_key', 'organisms']].copy()
coco_for_merge = coco_for_merge.rename(columns={
    'standard_inchi_key': 'inchi_key', 
    'organisms': 'species_info'
})
coco_for_merge['source'] = 'COCONUT'

print("COCONUT dataset shape:", coco_for_merge.shape)
coco_for_merge.head()
# Out:
# COCONUT dataset shape: (342, 3)
#                         inchi_key  \
# 158   BHQCQFFYRZLCQQ-OELDTZBJSA-N
# 723   GZSOSUNBTXMUFQ-YFAPSIMESA-N
# 735   OVBPIULPVIDEAO-LBPRGKRZSA-N
# 872   YWJXCIXBAKGUKZ-HJJNZUOJSA-N
# 1295  SJRACCTZSAUMGO-WIMVFMHDSA-N
#
#                                            species_info   source
# 158   Bos taurus|Bubalus bubalis|Calculus bovis arti...  COCONUT
# 723   Aesculus turbinata|Alnus alnobetula|Argyreia s...  COCONUT
# 735   FOOD SAKE|Foeniculum vulgare|Spinacia oleracea...  COCONUT
# 872   Aframomum amaniense|Alectoria divergens|Amaror...  COCONUT
# 1295        Ammi visnaga|Eranthis hyemalis (L.) Salisb.  COCONUT

# %%
# Combine all three datasets
all_species_data = pd.concat([
    sp3_for_merge,
    lotus_for_merge,
    coco_for_merge
], ignore_index=True)

print("Combined dataset shape:", all_species_data.shape)
print("Sources distribution:")
print(all_species_data['source'].value_counts())
print("\nSample of combined data:")
all_species_data.head(10)
# Out:
# Combined dataset shape: (1175, 3)
# Sources distribution:
# source
# LOTUS      480
# SP3        353
# COCONUT    342
# Name: count, dtype: int64
#
# Sample of combined data:
#                      inchi_key  \
# 0  AEDDIBAIWPIIBD-ZJKJAXBQSA-N
# 1  AEQDJSLRWYMAQI-UHFFFAOYSA-N
# 2  AHTRGGWSBFOEEG-BXDNVMCDSA-N
# 3  AIONOLUJZLIMTK-AWEZNQCLSA-N
# 4  AKZZXWNFVQXXFN-QHJPBWEBSA-N
# 5  AMBQHHVBBHTQBF-UOUCRYGSSA-N
# 6  AONLJCCUYGGOSW-PJERILTQSA-N
# 7  AQBZCCQCDWNNJQ-AUSIDOKSSA-N
# 8  AQRNEKDRSXYJIN-IRFILORWSA-N
# 9  ARGKVCXINMKCAZ-UZRWAPQLSA-N
#
#                                         species_info source
# 0  Cyclopia sessiliflora|Cyclopia genistoides|Cyc...    SP3
# 1  Corydalis turtschaninovii|Stephania venosa|Ech...    SP3
# 2  Fraxinus excelsior|Fraxinus excelsior|Fraxinus...    SP3
# 3  Citrus maxima|Citrus trifoliata|Citrus reticul...    SP3
# 4  Laggera crispata|Laggera crispata|Laggera cris...    SP3
# 5  Rhinanthus angustifolius|Rhinanthus angustifol...    SP3
# 6  Teucrium divaricatum|Teucrium microphyllum|Teu...    SP3
# 7  Millettia dura|Millettia dura|Millettia ferrug...    SP3
# 8  Alnus glutinosa|Alnus glutinosa|Alnus glutinos...    SP3
# 9  Citrus trifoliata|Citrus trifoliata|Citrus tri...    SP3

# %% [markdown]
# ### Create consolidated species dataset
#
# Now we'll create a consolidated version where all species information for each InChI key is merged into a single row.

# %%
# Group by InChI key and consolidate all species information
consolidated_species = (
    all_species_data
    .groupby('inchi_key')
    .agg({
        'species_info': lambda x: ' | '.join([str(info) for info in x if pd.notna(info)]),
        'source': lambda x: ' + '.join(sorted(set(x)))
    })
    .reset_index()
)

# Add compound information from PTFI
consolidated_species = consolidated_species.merge(
    ptfi_known[['inchi_key', 'element_id', 'element_name']], 
    on='inchi_key', 
    how='left'
)

# Reorder columns
consolidated_species = consolidated_species[[
    'element_id', 'element_name', 'inchi_key', 'species_info', 'source'
]]

print("Consolidated dataset shape:", consolidated_species.shape)
consolidated_species.head()
# Out:
# Consolidated dataset shape: (514, 5)
#                         element_id               element_name  \
# 0  MET_AEDDIBAIWPIIBD-ZJKJAXBQSA-N                 Mangiferin
# 1  MET_AEQDJSLRWYMAQI-UHFFFAOYSA-N                  NP-001740
# 2  MET_AHTRGGWSBFOEEG-BXDNVMCDSA-N                  NP-001314
# 3  MET_AIONOLUJZLIMTK-AWEZNQCLSA-N                 Hesperetin
# 4  MET_AKEUNCKRJATALU-UHFFFAOYSA-N  2,6-Dihydroxybenzoic acid
#
#                      inchi_key  \
# 0  AEDDIBAIWPIIBD-ZJKJAXBQSA-N
# 1  AEQDJSLRWYMAQI-UHFFFAOYSA-N
# 2  AHTRGGWSBFOEEG-BXDNVMCDSA-N
# 3  AIONOLUJZLIMTK-AWEZNQCLSA-N
# 4  AKEUNCKRJATALU-UHFFFAOYSA-N
#
#                                         species_info                 source
# 0  Cyclopia sessiliflora|Cyclopia genistoides|Cyc...  COCONUT + LOTUS + SP3
# 1  Corydalis turtschaninovii|Stephania venosa|Ech...            LOTUS + SP3
# 2  Fraxinus excelsior|Fraxinus excelsior|Fraxinus...          COCONUT + SP3
# 3  Citrus maxima|Citrus trifoliata|Citrus reticul...  COCONUT + LOTUS + SP3
# 4  Alangium platanifolium | Aniba riparia | Fallo...        COCONUT + LOTUS

# %%
# Show some statistics about the merged data
print("=== MERGED SPECIES DATABASE STATISTICS ===")
print(f"Total compounds with species data: {len(consolidated_species)}")
print(f"Compounds from SP3 only: {len(consolidated_species[consolidated_species['source'] == 'SP3'])}")
print(f"Compounds from LOTUS only: {len(consolidated_species[consolidated_species['source'] == 'LOTUS'])}")
print(f"Compounds from COCONUT only: {len(consolidated_species[consolidated_species['source'] == 'COCONUT'])}")
print(f"Compounds from multiple sources: {len(consolidated_species[consolidated_species['source'].str.contains('+', regex=False)])}")

# Detailed breakdown of combinations
print(f"\nDetailed source combinations:")
source_counts = consolidated_species['source'].value_counts()
for source, count in source_counts.items():
    if '+' in source:
        print(f"  {source}: {count}")

# Show an example of a compound with multiple sources
multi_source = consolidated_species[consolidated_species['source'].str.contains('+', regex=False)].head(1)
if not multi_source.empty:
    print(f"\nExample compound from multiple sources:")
    print(f"Compound: {multi_source.iloc[0]['element_name']}")
    print(f"Sources: {multi_source.iloc[0]['source']}")
    print(f"Species: {multi_source.iloc[0]['species_info'][:200]}...")  # First 200 chars
# Out:
# === MERGED SPECIES DATABASE STATISTICS ===
# Total compounds with species data: 514
# Compounds from SP3 only: 7
# Compounds from LOTUS only: 101
# Compounds from COCONUT only: 15
# Compounds from multiple sources: 391
#
# Detailed source combinations:
#   COCONUT + LOTUS + SP3: 265
#   LOTUS + SP3: 69
#   COCONUT + LOTUS: 45
#   COCONUT + SP3: 12
#
# Example compound from multiple sources:
# Compound: Mangiferin
# Sources: COCONUT + LOTUS + SP3
# Species: Cyclopia sessiliflora|Cyclopia genistoides|Cyclopia intermedia|Cyclopia maculata|Cyclopia falcata|Cyclopia subternata|Hedysarum denticulatum|Hypericum perforatum|Salacia reticulata|Fridericia patellif...

# %% [markdown]
# ### Export dataset

# %%
# Export the consolidated dataset
output_file = "../export_ptfi/natural_products_species_consolidated.csv"
consolidated_species.to_csv(output_file, index=False)
print(f"Consolidated species dataset exported to: {output_file}")

# Also export the raw combined data (before consolidation) for reference
raw_output_file = "../export_ptfi/natural_products_species_raw.csv" 
all_species_data.to_csv(raw_output_file, index=False)
print(f"Raw combined dataset exported to: {raw_output_file}")

print("\nFinal consolidated dataset preview:")
consolidated_species.head()
# Out:
# Consolidated species dataset exported to: ../export_ptfi/natural_products_species_consolidated.csv
# Raw combined dataset exported to: ../export_ptfi/natural_products_species_raw.csv
#
# Final consolidated dataset preview:
#                         element_id               element_name  \
# 0  MET_AEDDIBAIWPIIBD-ZJKJAXBQSA-N                 Mangiferin
# 1  MET_AEQDJSLRWYMAQI-UHFFFAOYSA-N                  NP-001740
# 2  MET_AHTRGGWSBFOEEG-BXDNVMCDSA-N                  NP-001314
# 3  MET_AIONOLUJZLIMTK-AWEZNQCLSA-N                 Hesperetin
# 4  MET_AKEUNCKRJATALU-UHFFFAOYSA-N  2,6-Dihydroxybenzoic acid
#
#                      inchi_key  \
# 0  AEDDIBAIWPIIBD-ZJKJAXBQSA-N
# 1  AEQDJSLRWYMAQI-UHFFFAOYSA-N
# 2  AHTRGGWSBFOEEG-BXDNVMCDSA-N
# 3  AIONOLUJZLIMTK-AWEZNQCLSA-N
# 4  AKEUNCKRJATALU-UHFFFAOYSA-N
#
#                                         species_info                 source
# 0  Cyclopia sessiliflora|Cyclopia genistoides|Cyc...  COCONUT + LOTUS + SP3
# 1  Corydalis turtschaninovii|Stephania venosa|Ech...            LOTUS + SP3
# 2  Fraxinus excelsior|Fraxinus excelsior|Fraxinus...          COCONUT + SP3
# 3  Citrus maxima|Citrus trifoliata|Citrus reticul...  COCONUT + LOTUS + SP3
# 4  Alangium platanifolium | Aniba riparia | Fallo...        COCONUT + LOTUS
